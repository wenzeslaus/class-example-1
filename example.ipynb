# %%
3 + 2
# Out:
# 5

# %%
import rasterio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import rasterio
#
# ModuleNotFoundError: No module named 'rasterio'
